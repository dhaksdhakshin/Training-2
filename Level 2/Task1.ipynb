# %%
import matplotlib.pyplot as plt
# %matplotlib inline

import numpy as np

# %%
x = np.arange(1,4)
y = np.arange(2,8,step = 2)

# %%
plt.plot(x,y,marker = 'o',linestyle = '-')
plt.xlabel("X-Axis")
plt.ylabel("Y-Axis")
plt.title("Line Chart")
# Out:
# Text(0.5, 1.0, 'Line Chart')
